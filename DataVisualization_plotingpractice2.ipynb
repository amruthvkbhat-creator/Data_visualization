# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthvkbhat-creator/Data_visualization/blob/main/DataVisualization_plotingpractice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib

import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.figure(figsize = (9,7))
labels=[ "python", "C++", "C#", "Ruby", "R"]
Data= [12,32,22,43,31]
colors= ["saddlebrown", "wheat", "crimson", "lightgray", "lightblue"]
explode= [0,0,0,0,0]

plt.pie(Data,labels= labels,explode= explode,colors =colors,autopct ="%.2f%%",shadow =True,startangle =270,wedgeprops={"width":0.3})


plt.title("This is my pie graph", fontsize=18)
# Out:
# ...
# Text(0.5, 1.0, 'This is my pie graph')

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(9,7))
labels=[ "python", "C++", "C#", "Ruby", "R"]
Data= [12,32,22,43,31]
colors= ["saddlebrown", "wheat", "crimson", "lightgray", "lightblue"]
width = 0.3
data_pets = [22,12,12,32,1]
pets_label = ["a","b","c","s","w"]
p_pie = ax.pie(Data,labels= labels,colors =colors,autopct ="%.2f%%",shadow =True,startangle =270,wedgeprops={"width":0.3})

pet_pie = ax.pie(data_pets,
                 radius = 1-width,
                 labels = pets_label,
                 labeldistance = 0.65,
                 wedgeprops={"width":width})

pet_pie = ax.pie(data_pets,
                 radius = 1-2*width,
                 labels = pets_label,
                 labeldistance = 0.65,
                 wedgeprops={"width":width})

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots(figsize = (9,7))
labels = ["python","C++", "C#", "Ruby","R"]
data =[12,32,22,43,50]
colors=["saddlebrown","wheat","crimson","lightgray","lightblue"]
width=0.3
data_pets=[22,54,34,67,12]
pets_label = ["Dog","Fish","Cat","owl","Donkey"]
p_pie = ax.pie(data,radius=1,labels=labels, colors=colors , wedgeprops={"width":width})

pet_pie = ax.pie(data_pets,
                radius = 1-width,
                labels=pets_label ,
                wedgeprops={"width":width})

pet_pie = ax.pie(data_pets,
                radius = 1- 2*width,
                labels=pets_label ,
                wedgeprops={"width":width})

# %%
import pandas as pd
import numpy as np
from google.colab import drive

drive.mount('/content/drive')


data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DataVisualization/Copy of iris.data.csv',  header=None,
                   names=["sepal_length", "sepal_width", "petal_length", "petal_width", "variety"])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      variety
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2685096672.py in <cell line: 0>()
#       3
#       4 # Calculate the correlation matrix
# ----> 5 correlation_matrix = data.corr(numeric_only=True)
#       6
#       7 # Create the heatmap
#
# AttributeError: 'numpy.ndarray' object has no attribute 'corr'

# %%
import matplotlib.pyplot as plt

import matplotlib.cbook as cbook
import matplotlib.patches as patches

with cbook.get_sample_data('grace_hopper.jpg') as image_file:
    image = plt.imread(image_file)

fig, ax = plt.subplots()
im = ax.imshow(image)
patch = patches.Circle((260, 200), radius=200, transform=ax.transData)
im.set_clip_path(patch)

ax.axis('off')
plt.show()

# %%
import functools

import matplotlib.pyplot as plt
import numpy as np

import matplotlib.animation as animation

# Setting up a random number generator with a fixed state for reproducibility.
rng = np.random.default_rng(seed=19680801)
# Fixing bin edges.
HIST_BINS = np.linspace(-4, 4, 100)

# Histogram our data with numpy.
data = rng.standard_normal(1000)
n, _ = np.histogram(data, HIST_BINS)

# %%
def animate(frame_number, bar_container):
    # Simulate new data coming in.
    data = rng.standard_normal(1000)
    n, _ = np.histogram(data, HIST_BINS)
    for count, rect in zip(n, bar_container.patches):
        rect.set_height(count)

    return bar_container.patches

# %%
import matplotlib.pyplot as plt
import numpy as np


def squiggle_xy(a, b, c, d):
    i = np.arange(0.0, 2*np.pi, 0.05)
    return np.sin(i*a)*np.cos(i*b), np.sin(i*c)*np.cos(i*d)


fig = plt.figure(figsize=(8, 8))
outer_grid = fig.add_gridspec(4, 4, wspace=0, hspace=0)

for a in range(4):
    for b in range(4):
        # gridspec inside gridspec
        inner_grid = outer_grid[a, b].subgridspec(3, 3, wspace=0, hspace=0)
        axs = inner_grid.subplots()  # Create all subplots for the inner grid.
        for (c, d), ax in np.ndenumerate(axs):
            ax.plot(*squiggle_xy(a + 1, b + 1, c + 1, d + 1))
            ax.set(xticks=[], yticks=[])

# show only the outside spines
for ax in fig.get_axes():
    ss = ax.get_subplotspec()
    ax.spines.top.set_visible(ss.is_first_row())
    ax.spines.bottom.set_visible(ss.is_last_row())
    ax.spines.left.set_visible(ss.is_first_col())
    ax.spines.right.set_visible(ss.is_last_col())

plt.show()

# %%
labels = ["sepal_length", "sepal_width", "petal_length", "petal_width", "variety"]
data = [12,2,4,1,4]
plt.bar(labels,data)
plt.xlabel("Features")
plt.ylabel("Values")
plt.title("Bar Graph", loc="left",fontsize = 23)
plt.grid()
plt.tight_layout()
plt.show()

# %%
labels = ["sepal_length", "sepal_width", "petal_length", "petal_width", "variety"]
data = [12,2,4,1,4]
plt.bar(labels,data)
plt.xlabel("Features")
plt.ylabel("Values")
plt.title("Bar Graph", loc="left",fontsize = 23)
plt.grid(True,     # Enable the grid
         axis='x', # Apply grid lines to the x-axis
         color='red',  # Set the color of the grid lines
         linestyle=':',# Set the linestyle to dashed
         linewidth=1.5, # Set the linewidth
         alpha=0.6,    # Set the transparency
         # You can add more Line2D properties here as needed
        )
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
time_points = np.arange(7) *5
velocity_obj1 = np.array([10, 15,20,20,30,15,0])
velocity_obj2 = np.array([10,12,15,12,20,10,0])
plt.figure(figsize=(9, 7),facecolor="lightyellow")
plt.plot(time_points, velocity_obj1, color='cornflowerblue', marker='o', linestyle='-', label='Velocity Obj 1', markersize=8, linewidth=2)
plt.plot(time_points, velocity_obj2, color='orangered', marker='X', linestyle='--', label='Velocity Obj 2', markersize=8, linewidth=2)
plt.ylabel("Velocity", fontsize=12)
plt.title("Velocity of Two Objects Over Time", loc="center", fontsize=20, fontweight='bold')
plt.legend(loc='upper left')
plt.grid(True,
         color='black',
         linestyle='--',
         linewidth=0.7,
         alpha=0.5,
        )
plt.tight_layout()
plt.show()

# %%
# Create the animation
# The interval controls the delay between frames in milliseconds
# The frames argument specifies the number of frames
ani = animation.FuncAnimation(fig, update, frames=len(time_points) + 1, interval=500, blit=True)

# Display the animation
from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
import plotly.graph_objects as go
import numpy as np

# Sample data (using the same data as the matplotlib example)
time_points = np.arange(7) * 5
velocity_obj1 = np.array([10, 15, 20, 20, 30, 15, 0])
velocity_obj2 = np.array([10, 12, 15, 12, 20, 10, 0])

# Create a Plotly figure
fig = go.Figure()

# Add the first line trace with enhanced hover and appearance
fig.add_trace(go.Scattergl(x=time_points, y=velocity_obj1,
                           mode='lines+markers',
                           name='Velocity Obj 1',
                           line=dict(color='royalblue', width=2), # Customize line color and width
                           marker=dict(color='royalblue', size=8, symbol='circle'), # Customize marker color, size, and symbol
                           hovertemplate='Time: %{x}s<br>Velocity: %{y}<br>Object: %{data.name}<extra></extra>')) # Custom hover template

# Add the second line trace with enhanced hover and appearance
fig.add_trace(go.Scattergl(x=time_points, y=velocity_obj2,
                           mode='lines+markers',
                           name='Velocity Obj 2',
                           line=dict(color='darkorange', width=2, dash='dash'), # Customize line color, width, and style
                           marker=dict(color='darkorange', size=8, symbol='diamond'), # Customize marker color, size, and symbol
                           hovertemplate='Time: %{x}s<br>Velocity: %{y}<br>Object: %{data.name}<extra></extra>')) # Custom hover template

# Update layout for title, axis labels, and add hover mode
fig.update_layout(title={
    'text': 'Velocity of Two Objects Over Time (Enhanced Plotly)',
    'yref': 'paper',
    'y':0.9,
    'x':0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, # Customize title appearance and position
                  xaxis_title='Time (s)',
                  yaxis_title='Velocity',
                  hovermode='x unified', # Unify hover across x-axis
                  template='plotly_white') # Use a different template

# Add a range slider for interactive zooming
# fig.update_layout(xaxis=dict(rangeslider=dict(visible=True)))

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
